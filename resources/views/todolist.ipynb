# %% [markdown]
# ### To-Do
# 1. Isi Materi Teks dan Video tiap pilar - High
# 2. Konten Quiz tiap pilar - High
# 3. Tambahkan Ranking untuk Gamification di pagePerforma - medium
# 4. Tambahkan UI Paralax home? - medium
#
# Buat Logo dan nama media pembelajaran - low
# Style UI page profile dan change password - low
# Perbaiki Isi konten Home - low
# Perbaiki isi konten page Tim pengembang - low
# Perbaiki isi konten page Sumber Referensi - low
